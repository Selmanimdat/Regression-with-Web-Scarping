# %% [markdown]
# # make auto regression model

# %%
# we will make auto regression

# %%
#libraries

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 80.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 80.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 20.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from pycaret.regression import*

# %%
import pandas as pd

# %%
#read data

# %%
df=pd.read_pickle('/content/clean_data.pickle')

# %%
#see first 5 cels

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023     90   120m²        2+1            1                   5
# 2  5 Aralık 2023      -   120m²        2+1            1                   5
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22   120m²        2+1            1                   5
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
#setup data

# %%
setup(data=df,target='Price')
# Out:
# <style type="text/css">
# #T_605da_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_605da" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_605da_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_605da_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_605da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_605da_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_605da_row0_col1" class="data row0 col1" >331</td>
#     </tr>
#     <tr>
#       <th id="T_605da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_605da_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_605da_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_605da_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#compare models

# %%
best_model= compare_models()
# Out:
# <style type="text/css">
# #T_d4c5e th {
#   text-align: left;
# }
# ...

# %%
# create best model

# %%
best_model = create_model('huber')
# Out:
# <style type="text/css">
# #T_0baf0_row10_col0, #T_0baf0_row10_col1, #T_0baf0_row10_col2, #T_0baf0_row10_col3, #T_0baf0_row10_col4, #T_0baf0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0baf0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0baf0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0baf0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0baf0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0baf0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0baf0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0baf0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
#save model

# %%
import joblib

# %%
joblib.dump(best_model,"model_scarp_houseprices.joblib")
# Out:
# ['model_scarp_houseprices.joblib']

# %%
#sources

# %% [markdown]
# -Zafer Acar Notes -[https://poe.com/chat/2rhcfi4djoj4u359vfr]
