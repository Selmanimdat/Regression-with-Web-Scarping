# %% [markdown]
# # Data cleaning

# %%
# we will make data cleaning

# %%
#libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#read data

# %%
df=pd.read_csv("rent_houses.csv")

# %%
#see first 5 cels

# %%
df.head()
# Out:
#      İlan Tarihi  İlan no Net m² Brüt m² Oda Sayısı Banyo Sayısı  \
# 0  5 Aralık 2023  4841963    105   130m²        3+1            2
# 1  5 Aralık 2023  4805363    NaN     NaN        NaN          NaN
# 2  5 Aralık 2023  4841134      -     NaN        NaN          NaN
# 3  5 Aralık 2023  4840931     58    79m²        2+1            1
# 4  5 Aralık 2023  4948471     22     NaN        NaN          NaN
#
#   Binadaki Kat Sayısı                      Isıtma Tipi Konut Şekli  \
# 0                  10                            Klima     Ara Kat
# 1                 NaN                 Kombi (Doğalgaz)         NaN
# 2                 NaN                     Soba (Kömür)         NaN
# 3                   8  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat
# 4                 NaN                            Klima         NaN
#
#   Bulunduğu Kat    Bina Yaşı Görüntülü Ev Gezintisi\n?      Mobilya Durumu  \
# 0             6   6-10 arası                         ?  Eşyalı (Mobilyalı)
# ...

# %%
#EDA

# %%
#data info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   İlan Tarihi                666 non-null    object
#  1   İlan no                    666 non-null    int64
#  2   Net m²                     548 non-null    object
#  3   Brüt m²                    469 non-null    object
#  4   Oda Sayısı                 453 non-null    object
#  5   Banyo Sayısı               456 non-null    object
#  6   Binadaki Kat Sayısı        517 non-null    object
#  7   Isıtma Tipi                532 non-null    object
#  8   Konut Şekli                306 non-null    object
#  9   Bulunduğu Kat              520 non-null    object
#  10  Bina Yaşı                  567 non-null    object
#  11  Görüntülü Ev Gezintisi
# ?   310 non-null    object
#  12  Mobilya Durumu             383 non-null    object
# ...

# %%
#data corelations

# %%
df.corr()
# Out:
#           İlan no    Parsel
# İlan no  1.000000 -0.104274
# Parsel  -0.104274  1.000000

# %%
#data statistics

# %%
df.describe().T
# Out:
#          count          mean            std       min        25%        50%  \
# İlan no  666.0  4.852286e+06  288205.310633  491024.0  4870947.5  4941199.0
# Parsel    10.0  4.500000e+00       7.261007       1.0        2.0        2.0
#
#                 75%        max
# İlan no  4970616.75  4976724.0
# Parsel         3.00       25.0

# %%
#see mising values

# %%
df.isnull().sum()
# Out:
# İlan Tarihi                    0
# İlan no                        0
# Net m²                       118
# Brüt m²                      197
# Oda Sayısı                   213
# Banyo Sayısı                 210
# Binadaki Kat Sayısı          149
# Isıtma Tipi                  134
# Konut Şekli                  360
# Bulunduğu Kat                146
# Bina Yaşı                     99
# Görüntülü Ev Gezintisi\n?    356
# Mobilya Durumu               283
# Kullanım Durumu              149
# Depozito                     166
# Aidat                        222
# Krediye Uygun                  0
# Price                          0
# m²                           469
# Bölüm/Oda Sayısı             583
# Kimden                       384
# Tapu Durumu                  525
# Yapının Durumu               440
# Devren                       657
# Hayvan Dostu Patili Evler    625
# Yapı Tipi                    661
# Kat Yüksekliği               660
# Arsa Alanı                   658
# ...

# %%
#data shape

# %%
df.shape
# Out:
# (666, 38)

# %%
# rows %80 is

# %%
966*(80/100)
# Out:
# 772.8000000000001

# %% [markdown]
# ### preprocesing

# %%
columns_to_drop = ["İlan no", "Görüntülü Ev Gezintisi\n?", "Parselli"]
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
# chek

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)         NaN             5  11-15 arası
# 2                     Soba (Kömür)         NaN           NaN   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima         NaN           NaN          NaN
#
# ...

# %%
df["Yapı Tipi"].unique()
# Out:
# array([nan, 'Betonarme'], dtype=object)

# %%
df["Yapı Tipi"].mode()
# Out:
# 0    Betonarme
# dtype: object

# %%
#fill with mode because generakky istanbul builds are like that

# %%
df["Yapı Tipi"].fillna(df["Yapı Tipi"].mode()[0], inplace=True)

# %%
#check

# %%
df["Yapı Tipi"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)         NaN             5  11-15 arası
# 2                     Soba (Kömür)         NaN           NaN   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima         NaN           NaN          NaN
#
# ...

# %%
df["Dış Cephe"].unique()
# Out:
# array([nan, 'Cam Giydirme', 'Taş Kaplama', 'Betonarme'], dtype=object)

# %%
df["Dış Cephe"].mode()
# Out:
# 0       Betonarme
# 1    Cam Giydirme
# 2     Taş Kaplama
# dtype: object

# %%
df["Hayvan Dostu Patili Evler"].unique()
# Out:
# array([nan, 'Evet'], dtype=object)

# %%
df["Hayvan Dostu Patili Evler"]=df["Hayvan Dostu Patili Evler"].map({'Evet':1,'Yes':1})

# %%
df["Hayvan Dostu Patili Evler"].fillna(0, inplace=True)

# %%
df["Hayvan Dostu Patili Evler"].isnull().sum()
# Out:
# 0

# %%
df["Hayvan Dostu Patili Evler"]=df["Hayvan Dostu Patili Evler"].astype("int32")

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)         NaN             5  11-15 arası
# 2                     Soba (Kömür)         NaN           NaN   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima         NaN           NaN          NaN
#
# ...

# %%
df["Isıtma Tipi"].unique()
# Out:
# array(['Klima', 'Kombi (Doğalgaz)', 'Soba (Kömür)',
#        'Merkezi Sistem (Isı Payı Ölçer)', 'Merkezi Sistem', nan,
#        'Soba (Doğalgaz)', 'Yerden Isıtma', 'Yok', 'Fancoil',
#        'Air Conditioner', 'Kombi (Elektrikli)',
#        'Central System (Heat Share Meter)', 'Kalorifer (Doğalgaz)',
#        'Combi Boiler (Natural Gas)', 'Central System', 'None',
#        'Kat Kaloriferi', 'Güneş Enerjisi'], dtype=object)

# %%
df["Isıtma Tipi"] = df["Isıtma Tipi"].replace({
    'Central System (Heat Share Meter)': 'Merkezi Sistem (Isı Payı Ölçer)',
    'Combi Boiler (Natural Gas)': 'Kombi (Doğalgaz)',
    'Kalorifer (Akaryakıt)': 'Kalorifer (Doğalgaz)',
})

# %%
df["Isıtma Tipi"].mode()
# Out:
# 0    Kombi (Doğalgaz)
# dtype: object

# %%
df["Isıtma Tipi"].fillna(df["Isıtma Tipi"].mode()[0], inplace=True)

# %%
df["Hayvan Dostu Patili Evler"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)         NaN             5  11-15 arası
# 2                     Soba (Kömür)         NaN           NaN   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima         NaN           NaN          NaN
#
# ...

# %%
df["Konut Şekli"].unique()
# Out:
# array(['Ara Kat', nan, 'En Üst Kat', 'Tripleks', 'Çatı Dubleksi',
#        'Intermediate Floor', 'Bahçe Dubleksi', 'Giriş Kat', 'Bahçe Katı',
#        'Fourlex', 'First Floor', 'Ters Dubleks', 'Teras Katı', 'Dubleks'],
#       dtype=object)

# %%
df["Konut Şekli"] = df["Konut Şekli"].replace({
    'Intermediate Floor': 'Ara Kat',
    'En Üst Kat': 'Teras Katı',
    'Giriş Kat': 'Bahçe Katı',
})

# %%
df["Konut Şekli"].mode()
# Out:
# 0    Ara Kat
# dtype: object

# %%
df["Konut Şekli"].fillna(df["Konut Şekli"].mode()[0], inplace=True)

# %%
df["Konut Şekli"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat           NaN   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat           NaN          NaN
#
# ...

# %%
df["Bulunduğu Kat"].unique()
# Out:
# array(['6', '5', nan, '7', '20 ve üzeri', '2', '3', 'Giriş Katı', '9',
#        '4', '18', 'Müstakil', '13', '16', '14', '1', '15', '12',
#        'Yüksek Giriş', 'Bahçe katı', 'Komple', 'Garden Floor', '11',
#        'Zemin Kat', '8', '10', 'Bodrum Kat', 'En Üst Kat',
#        'Raised First Floor', 'Kot 4', 'Kot 2', '17', 'Teras Kat', 'Kot 3',
#        'Kot 1', 'Çatı Katı'], dtype=object)

# %%
df["Bulunduğu Kat"] = df["Bulunduğu Kat"].replace({
    'Giriş Katı': '1',
    'Kot 1': '1',
    'Zemin Kat': '0',
    'Bahçe katı': '0',  
    'En Üst Kat': '20 ve üzeri',
    '20+': '20 ve üzeri',
    'Teras Kat': '20 ve üzeri',
    'Çatı Katı': '20 ve üzeri',
    'Yüksek Giriş': '3',
    'Kot 2': '2',
    "Komple":"Müstakil"
})

# %%
df["Bulunduğu Kat"].fillna(df["Bulunduğu Kat"].mode()[0], inplace=True)

# %%
df["Bulunduğu Kat"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1          NaN
#
# ...

# %%
df["Bina Yaşı"].unique()
# Out:
# array(['6-10 arası', '11-15 arası', '0', nan, '26-30 arası',
#        '21-25 arası', '16-20 arası', '36-40 arası', '4', '3', '2',
#        '31-35 arası', 'Between 31-35', '1', '40 ve üzeri', 'Between 6-10',
#        'Between 26-30', 'Between 21-25', '5', 'Between 11-15'],
#       dtype=object)

# %%
df["Bina Yaşı"] = df["Bina Yaşı"].replace({
    'Between 6-10': '6-10 arası',
    'Between 11-15': '11-15 arası',
    'Between 21-25': '21-25 arası',
    'Between 26-30': '26-30 arası',
    'Between 31-35': '31-35 arası',
})

# %%
df["Bina Yaşı"].fillna(df["Bina Yaşı"].mode()[0], inplace=True)

# %%
df["Bulunduğu Kat"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Mobilya Durumu"].unique()
# Out:
# array(['Eşyalı (Mobilyalı)', nan, 'Eşyasız', 'Sadece Beyaz Eşya',
#        'Sadece Mutfak', 'Unfurnished', 'Furnished'], dtype=object)

# %%
df["Mobilya Durumu"] = df["Mobilya Durumu"].replace({
    'Furnished': 'Eşyalı (Mobilyalı)',
    'Only Major Appliances': 'Sadece Beyaz Eşya',
    'Unfurnished': 'Eşyasız',
})

# %%
df["Mobilya Durumu"].mode()
# Out:
# 0    Eşyasız
# dtype: object

# %%
df["Mobilya Durumu"].fillna(df["Mobilya Durumu"].mode()[0], inplace=True)

# %%
df["Mobilya Durumu"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Kullanım Durumu"].unique()
# Out:
# array(['Boş', nan, 'Kiracılı', 'Vacant', 'Occupied By Property Owner',
#        'Mülk Sahibi'], dtype=object)

# %%
df["Kullanım Durumu"] = df["Kullanım Durumu"].replace({
    'Vacant': 'Boş',
    'Occupied By Property Owner': 'Mülk Sahibi',
})

# %%
df["Kullanım Durumu"].fillna(df["Kullanım Durumu"].mode()[0], inplace=True)

# %%
df["Kullanım Durumu"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Yapının Durumu"].unique()
# Out:
# array([nan, 'İkinci El', 'Sıfır', 'Second Hand', 'New Building'],
#       dtype=object)

# %%
df["Yapının Durumu"] = df["Yapının Durumu"].replace("Second Hand","İkinci El")

# %%
df["Yapının Durumu"].fillna(df["Yapının Durumu"].mode()[0], inplace=True)

# %%
df["Yapının Durumu"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Depozito"].unique()
# Out:
# array(['0 TL', '34.000 TL', nan, '8.300 TL', '60.000 TL', '46.000 TL',
#        '21.000 TL', '30.000 TL', '17.000 TL undefined', '20.000 TL',
#        '10.000 TL', '0 TL undefined', '18.000 USD', '45.000 TL',
#        '300.000 TL', '35.000 TL', '50.000 TL', '6.500 TL', '570.000 TL',
#        '160.000 TL', '40.000 TL', '100.000 TL', '14.250 TL', '64.000 TL',
#        '25.000 TL', '14.500 TL', '17.000 TL', '12.000 TL', '106.400 TL',
#        '8.000 TL', '16.500 TL', '20.000 TL undefined', '14.000 TL',
#        '8.500 TL', '90.000 TL', '22.000 TL', '47.000 TL', '70.000 TL',
#        '18.000 TL undefined', '40.000 TL undefined', '24.000 TL',
#        '56.000 TL', '28.000 TL undefined', '13.000 TL', '560.000 TL',
#        '260.000 TL undefined', '15.000 TL', '110.000 TL', '65.000 TL',
#        '17.500 TL', '37.000 TL', '7.000 TL', '13.000.000 TL', '12.500 TL',
#        '16.000 TL', '42.000 TL', '12.000 TL undefined', '27.000 TL',
# ...

# %%
df["Depozito"] = df["Depozito"].apply(lambda x: ''.join(filter(str.isdigit, str(x))) if pd.notna(x) else x)

# %%
df["Depozito"].unique()
# Out:
# array(['0', '34000', nan, '8300', '60000', '46000', '21000', '30000',
#        '17000', '20000', '10000', '18000', '45000', '300000', '35000',
#        '50000', '6500', '570000', '160000', '40000', '100000', '14250',
#        '64000', '25000', '14500', '12000', '106400', '8000', '16500',
#        '14000', '8500', '90000', '22000', '47000', '70000', '24000',
#        '56000', '28000', '13000', '560000', '260000', '15000', '110000',
#        '65000', '17500', '37000', '7000', '13000000', '12500', '16000',
#        '42000', '27000', '500000', '76000', '23000', '9500', '220000',
#        '52000', '66250', '27500', '10500', '19950', '95000', '1000000',
#        '80000', '26000', '38000', '33000', '13900', '32000', '248200',
#        '9000', '54450', '240000', '31000', '16800', '48000', '44000',
#        '14050', '5000000', '3000000', '200000', '226000', '55000',
#        '142000'], dtype=object)

# %%
df["Depozito"].isnull().sum()
# Out:
# 166

# %%
df["Depozito"].fillna(df["Depozito"].mode()[0], inplace=True)

# %%
df["Depozito"]=df["Depozito"].astype("int32")

# %%
df["Depozito"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Aidat"].unique()
# Out:
# array(['0 TL (aylık)', nan, '100 TL (aylık)', '50 TL (aylık)',
#        '450 TL (aylık)', '1.950 TL (aylık)', '1.675 TL (aylık)',
#        '200 TL (aylık)', '550 TL (aylık)', '600 TL (aylık)',
#        '728 TL (aylık)', '17.000 TL (aylık)', '16.700 TL (aylık)',
#        '1.300 TL (aylık)', '1.786 TL (aylık)', '250 TL (aylık)',
#        '2.190 TL (aylık)', '1.250 TL (aylık)', '1.850 TL (aylık)',
#        '150 TL (aylık)', '1.000 TL (aylık)', '1 TL (aylık)',
#        '60 TL (aylık)', '30 TL (aylık)', '1.400 TL (aylık)',
#        '13.750 TL (aylık)', '2.750 TL (aylık)', '1.350 TL (aylık)',
#        '1.071 TL (aylık)', '4.000 TL (aylık)', '3.600 TL (aylık)',
#        '2.600 TL (aylık)', '650 TL (aylık)', '444 TL (aylık)',
#        '2.000 TL (aylık)', '175 TL (aylık)', '306 TL (aylık)',
#        '75 TL (aylık)', '420 TL (aylık)', '10.000 TL (aylık)',
#        '400 TL (aylık)', '3.500 TL (aylık)', '1.500 TL (aylık)',
#        '20 TL (aylık)', '8.260 TL (aylık)', '1.100 TL (aylık)',
# ...

# %%
df["Aidat"] = df["Aidat"].apply(lambda x: ''.join(filter(str.isdigit, str(x))) if pd.notna(x) else x)

# %%
df["Aidat"].isnull().sum()
# Out:
# 222

# %%
df["Aidat"].fillna(df["Aidat"].mode()[0], inplace=True)

# %%
df["Aidat"]=df["Aidat"].astype("int32")

# %%
df["Aidat"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df.drop("Krediye Uygun",axis=1,inplace=True)

# %%
df.drop("Kimden",axis=1,inplace=True)

# %%
df.drop("Takasa Uygun",axis=1,inplace=True)

# %%
columns_to_drop = ["Tavan Yüksekliği", "Zemin Etüdlü", "Kat Yüksekliği","Devren"]
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["Tapu Durumu"].unique()
# Out:
# array([nan, 'Kat Mülkiyeti', 'Kat İrtifakı', 'İskanı Alınmış',
#        'Arsa Tapulu', 'Bilinmiyor', 'Hisseli Tapu', 'Condominium',
#        'Müstakil Parsel', 'Land Title'], dtype=object)

# %%
df["Tapu Durumu"] = df["Tapu Durumu"].replace({
    'Condominium': 'Kat Mülkiyeti',
    'Arsa Tapulu': 'Müstakil Parsel',
    'Zilliyet': 'Müstakil Parsel'
})

# %%
df["Tapu Durumu"].fillna(df["Tapu Durumu"].mode()[0], inplace=True)

# %%
df["Tapu Durumu"].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df["m²"].unique()
# Out:
# array([nan, '170m²', '200m²', '23m²', '120m²', '75m²', '76m²', '55m²',
#        '270m²', '310m²', '77m²', '80m²', '90m²', '70m²', '660m²', '100m²',
#        '720m²', '740m²', '13530m²', '1350m²', '155m²', '400m²', '45m²',
#        '302m²', '140m²', '350m²', '35m²', '1000m²', '15m²', '150m²',
#        '763m²', '180m²', '300m²', '12000m²', '2800m²', '380m²', '65m²',
#        '28m²', '240m²', '650m²', '280m²', '25m²', '235m²', '1100m²',
#        '210m²', '225m²', '1750m²', '320m²', '11000m²', '130m²', '250m²',
#        '68m²', '674m²', '230m²', '160m²', '1200m²', '790m²', '111m²',
#        '60m²', '920m²', '450m²', '3500m²', '88m²', '750m²', '101m²',
#        '138m²', '165m²', '1850m²', '2750m²', '4059m²', '30000m²',
#        '1455m²', '2500m²', '1800m²', '286m²', '2m²', '157m²', '143m²',
#        '800m²', '2220m²', '110m²', '115m²', '91m²', '285m²', '50m²',
#        '550m²', '205m²', '1480m²', '600m²', '1530m²', '15000m²', '360m²',
# ...

# %%
df["m²"].isnull().sum()
# Out:
# 469

# %%
#:(

# %%
df.drop("m²", axis=1, inplace=True)

# %%
df["Bölüm/Oda Sayısı"].unique()
# Out:
# array([nan, '2', '1', '3', '21-30 arası', '6', '4', '5', '7', '9',
#        '31-40 arası', '10'], dtype=object)

# %%
df["Bölüm/Oda Sayısı"].isnull().sum()
# Out:
# 583

# %%
df.drop("Bölüm/Oda Sayısı", axis=1, inplace=True)

# %%
columns_to_drop = ["Kapalı Alan","Dış Cephe","Ada","Parsel","Arsa Alanı","İmar Durumu","Kapasite"]
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023    NaN     NaN        NaN          NaN                 NaN
# 2  5 Aralık 2023      -     NaN        NaN          NaN                 NaN
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22     NaN        NaN          NaN                 NaN
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
df.isnull().sum()
# Out:
# İlan Tarihi                    0
# Net m²                       118
# Brüt m²                      197
# Oda Sayısı                   213
# Banyo Sayısı                 210
# Binadaki Kat Sayısı          149
# Isıtma Tipi                    0
# Konut Şekli                    0
# Bulunduğu Kat                  0
# Bina Yaşı                      0
# Mobilya Durumu                 0
# Kullanım Durumu                0
# Depozito                       0
# Aidat                          0
# Price                          0
# Tapu Durumu                    0
# Yapının Durumu                 0
# Hayvan Dostu Patili Evler      0
# Yapı Tipi                      0
# dtype: int64

# %%
import pandas as pd

def auto_fill_missing_values(df, exclude_columns=None):
    """
    Automatically fill missing values in a DataFrame, excluding specified columns.
    """
    # Separate columns by data type
    numerical_columns = df.select_dtypes(include='number').columns
    categorical_columns = df.select_dtypes(exclude='number').columns

    # Exclude specified columns
    if exclude_columns:
        numerical_columns = numerical_columns.difference(exclude_columns)
        categorical_columns = categorical_columns.difference(exclude_columns)

    # Fill missing values for numerical columns with the mean
    df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

    # Fill missing values for categorical columns with the mode
    df[categorical_columns] = df[categorical_columns].apply(lambda x: x.fillna(x.mode().iloc[0]))

    return df

# Example usage: Exclude columns 'column1' and 'column2'
df = auto_fill_missing_values(df)
#belong to chatgpt

# %%
df.isnull().sum()
# Out:
# İlan Tarihi                  0
# Net m²                       0
# Brüt m²                      0
# Oda Sayısı                   0
# Banyo Sayısı                 0
# Binadaki Kat Sayısı          0
# Isıtma Tipi                  0
# Konut Şekli                  0
# Bulunduğu Kat                0
# Bina Yaşı                    0
# Mobilya Durumu               0
# Kullanım Durumu              0
# Depozito                     0
# Aidat                        0
# Price                        0
# Tapu Durumu                  0
# Yapının Durumu               0
# Hayvan Dostu Patili Evler    0
# Yapı Tipi                    0
# dtype: int64

# %%
df.head()
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023     90   120m²        2+1            1                   5
# 2  5 Aralık 2023      -   120m²        2+1            1                   5
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22   120m²        2+1            1                   5
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
#target

# %%
df["Price"] = df["Price"].apply(lambda x: ''.join(filter(str.isdigit, str(x))) if pd.notna(x) else x)

# %%
df["Price"]=df["Price"].astype("int32")

# %%
df.head()# oda sayısı toplanabilir
# Out:
#      İlan Tarihi Net m² Brüt m² Oda Sayısı Banyo Sayısı Binadaki Kat Sayısı  \
# 0  5 Aralık 2023    105   130m²        3+1            2                  10
# 1  5 Aralık 2023     90   120m²        2+1            1                   5
# 2  5 Aralık 2023      -   120m²        2+1            1                   5
# 3  5 Aralık 2023     58    79m²        2+1            1                   8
# 4  5 Aralık 2023     22   120m²        2+1            1                   5
#
#                        Isıtma Tipi Konut Şekli Bulunduğu Kat    Bina Yaşı  \
# 0                            Klima     Ara Kat             6   6-10 arası
# 1                 Kombi (Doğalgaz)     Ara Kat             5  11-15 arası
# 2                     Soba (Kömür)     Ara Kat             1   6-10 arası
# 3  Merkezi Sistem (Isı Payı Ölçer)     Ara Kat             7            0
# 4                            Klima     Ara Kat             1   6-10 arası
#
# ...

# %%
#save clean data

# %%
import pickle

# %%
with open("clean_data.pickle", 'wb') as file:
    pickle.dump(df, file)

# %% [markdown]
# -Zafer Acar Notes -[https://poe.com/chat/2rhcfi4djoj4u359vfr]
